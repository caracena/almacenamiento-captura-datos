# %% [markdown]
# ## Web scraping

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Extraer el título de la página de python.org

# %%
# !pip install beautifulsoup4
# !pip install requests

# %%
## usando urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup
 
html = urlopen("https://www.python.org/")

res = BeautifulSoup(html.read(),"html5lib")
 
print(res.title.text)
# Out:
# Welcome to Python.org

# %%
## usando requests
import requests

r = requests.get("https://www.python.org/")

res = BeautifulSoup(r.text,"html5lib")
 
print(res.title.text)
# Out:
# Welcome to Python.org

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Extraer notebooks de pc factory

# %%
r = requests.get("https://www.pcfactory.cl/notebooks?categoria=735&papa=636")
res = BeautifulSoup(r.text,"html.parser")
print(res.title.text)
# Out:
# Venta de los mejores computadores portátiles | PC Factory

# %%
npaginas = res.find('span', {'id': 'pag_ter2'}).text
print("Número de páginas:", npaginas)
# Out:
# Número de páginas: 3

# %%
bd = []

for n in range(int(npaginas)):
    req = requests.get("https://www.pcfactory.cl/notebooks?categoria=735&papa=636&pagina=" + str(n + 1))

    res = BeautifulSoup(req.text,"html.parser")

    notebooks = res.find_all('div', {'class': 'wrap-caluga-matrix'})

    for n in notebooks:
        marca = n.find('span', {'class': 'marca'}).text
        nombre = n.find('span', {'class': 'nombre'}).text
        precio = n.find('meta', {'itemprop': 'price'})['content']

        bd.append({"brand": marca, "name": nombre, "price": int(float(precio))})

# %%
import pandas as pd

df = pd.DataFrame(bd)
df
# Out:
#           brand                                               name    price
# 0      Gear  ®   Notebook Lotus 14" FHD Celeron N3350 4GB 128GB...   174590
# 1        HP  ®   Notebook 240 G6  Celeron N4000 4GB 500GB  Free...   184290
# 2        HP  ®   Notebook 245 G6 14" HD AMD E2-9000e 4GB 500GB ...   193990
# 3        HP  ®   Notebook 240 G7 14" HD Celeron N4000 4GB 500GB...   194990
# 4      Asus  ®   Notebook X540MA-GQ070T Intel® Celeron® N4000 4...   199990
# 5    Lenovo  ®   Notebook Ideapad 330 15.6" HD AMD A6-9225 4GB ...   219990
# 6      Asus  ®   Notebook X507UA 15.6" HD Pentium Gold N4417 4G...   229990
# 7    Lenovo  ®   Notebook 330 14" HD AMD A4-9125 4GB 500GB Wind...   229990
# 8      Gear  ®   Notebook Lotus 14" FHD Celeron N3350 4GB 128GB...   237490
# 9        HP  ®   Notebook 15.6" HD Intel Pentium Gold 4417U 4GB...   259990
# 10       HP  ®   Notebook 14" HD Intel Pentium Gold 4417U 8GB 2...   269990
# 11       HP  ®   Notebook 250 G7 15.6" HD Intel i3-7020U 4GB 1T...   279990
# 12     Asus  ®   Notebook Ultraliviano VivoBook 14 X420UA 14" F...   279990
# 13       HP  ®   Notebook 240 G7 14" HD Intel i3-7020U 4GB 1TB ...   281290
# 14       HP  ®   Notebook 240 G6 14" HD Intel i3-7020U 4GB 1TB ...   281290
# 15     Acer  ®   Notebook Aspire 5 15.6" Ryzen 3 4GB 256GB SSD ...   310390
# 16       HP  ®   Notebook 14" HD Intel i3-7020U 4GB+16GB Optane...   329990
# 17       HP  ®   Notebook 14" HD Intel i3-1005G1 4GB + 16GB Opt...   339990
# 18       HP  ®   Notebook 240 G7 14" HD Intel i5-8265U 4GB 1TB ...   349990
# 19   Lenovo  ®   Notebook Ultraliviano S340 14" HD  Ryzen3 -320...   349990
# 20       HP  ®   Notebook 240 G6 14" HD Intel i5-7200U 4GB 1TB ...   368590
# 21       HP  ®   Notebook 14" FHD Ryzen 3-3200U 8GB 256GB SSD W...   368590
# 22       HP  ®   Notebook 250 G7 15.6" HD Intel i3-7020U 8GB 1T...   378290
# 23     Asus  ®   Notebook Ultraliviano VivoBook 14" FHD  Intel ...   379990
# 24     Dell  ®   Notebook Dell Inspiron 3481 14" HD Intel i3-70...   379990
# 25       HP  ®   Notebook 240 G6 14" HD Intel i5-7200U 4GB 1TB ...   397690
# 26     Asus  ®   Notebook 14" FHD X412FJ Intel i3-8145U 4GB + 1...   399990
# 27     Dell  ®   Notebook Dell Inspiron 3481 14" HD Intel i3-70...   399990
# 28       HP  ®   Notebook 14" FHD Intel i5-8265U 8GB 256GB SSD ...   399990
# 29     Acer  ®   Notebook Ultraliviano Swift 3 14" FHD Intel i3...   407390
# ..          ...                                                ...      ...
# 108     MSI  ®   Notebook Pro Prestige Intel i7-10710U GTX 1650...  1357990
# 109    Dell  ®   Notebook Gamer G5 5590 Intel i7-9750H RTX 2060...  1367690
# 110    Dell  ®   Notebook Gamer G7 Intel i7-8750H RTX 2060 6GB ...  1454990
# 111    Dell  ®   Notebook Ultraliviano XPS 13.3" FHD Intel i5-8...  1454990
# 112  Lenovo  ®   Notebook Ultraliviano Yoga S940 14" FHD Intel ...  1499990
# 113     MSI  ®   Notebook Pro P65 Creator 9SE Intel i7-9750H RT...  1551990
# 114     MSI  ®   Notebook Gamer GL63 8SE Intel i7-8750H NVIDIA ...  1551990
# 115    Asus  ®   Notebook Gamer G531GU Intel i7-9750H GTX 1660T...  1648990
# 116      HP  ®   Notebooks Gamer Omen i7-9750H RTX 2080 Max-Q 8...  1775090
# 117     MSI  ®   Notebook Gamer GE75 Raider 9SE Intel i7-9750H ...  1842990
# 118    Dell  ®   Notebook Gamer Alienware 15 R3 Intel i7-8750H ...  1842990
# 119     MSI  ®   Notebook Pro WS65 9TJ Intel i7-9750H NVIDIA Qu...  1939990
# 120    Asus  ®   Notebook Gamer ROG Intel i7-9750H RTX 2060 6GB...  1939990
# 121    Dell  ®   Notebook Gamer Alienware m15 Intel i7-8750H RT...  1988490
# 122    Asus  ®   Notebook Gamer ROG G531GW Intel i7-9750H RTX 2...  2036990
# 123    Dell  ®   Notebook Gamer Alienware M15 Intel i7-8750H RT...  2085490
# 124    Dell  ®   Notebook 2en1 XPS 7390 Intel i7 1065-G7 16GB 5...  2133990
# 125    Asus  ®   Notebook Ultraliviano ZenBook Pro Intel i9-895...  2149990
# 126     MSI  ®   Notebook Gamer GS75 Stealth 9SF Intel i7-9750H...  2279490
# 127    Acer  ®   Notebook Gamer Predator Triton 500 Intel i7-87...  2327990
# 128  Lenovo  ®   Notebook Gamer Legion Y740 Intel i7-8750H RTX ...  2327990
# 129    Asus  ®   Notebook Gamer ROG Zephyrus GX501GI-EI030T i7-...  2376490
# 130    Asus  ®   Notebook Gamer G731GW-EV085T i7-9750H RTX 2070...  2424990
# 131    Dell  ®   Notebook Gamer Dell Alienware 15 R2 Intel i7-9...  2521990
# 132    Asus  ®   Notebook Gamer ROG GX531GXR Intel i7 RTX2080 M...  2715990
# 133   Razer  ®   Notebook Gamer Razer Blade  Intel i7-8750H RTX...  3199990
# 134    Asus  ®   Notebook Gamer ROG Intel i7-9750H RTX 2080 8GB...  3297990
# 135      HP  ®   Notebook OMEN X Intel i9-9880H RTX 2080 8GB 15...  3588990
# 136    Asus  ®   Notebook Gamer ROG G703GXR Intel i9-9980HK RTX...  3782990
# 137     MSI  ®   Notebook Gamer GT76 Titan DT 9SG Intel i9- 990...  3928490
#
# [138 rows x 3 columns]

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# Extraer productos y precios de linio

# %%
import requests
productos = []
for i in range(3):
    r = requests.get("https://www.linio.cl/c/computacion/pc-portatil?page=" + str(i+1))
    res = BeautifulSoup(r.text,"html5lib")
    products = res.find_all('div', {'class':'catalogue-product row'})
    for p in products:
        title = p.find('meta', {'itemprop':'name'})
        price = p.find('meta', {'itemprop':'price'})
        if title:
            print(title['content'])
        if price:
            print(price['content'])
        productos.append({'title':title['content'], 'price':price['content']})
# Out:
# Notebook 2-en-1 HP X360 14-cd0003la, Intel Core i3, Windows 10, 4 GB, HDD 500 GB de 14" HD Touch
# 319990.00
# Notebook Lenovo V145, AMD A4, FreeDOS (Sin Sistema Operativo), 4 GB, HDD 500 GB de 14" HD
# 139990.00
# Notebook Lenovo V130-14IGM, Intel Celeron, Windows 10, 4 GB, HDD 500 GB de 14" HD
# 179990.00
# Notebook MSI GL73, Intel Core i7 9ª Gen, Win10, 16 GB, SSD 256 GB, GeForce 4 GB de 17.3" FHD
# 899000.00
# Notebook ZenBook Pro Duo Intel Core i9 32GB - 1TB SSD 15.6'
# 2899990.00
# NOTEBOOK LENOVO V145-15AST AMD A6-9225 4GB 500GB WINDOWS 10 HOME
# 163990.00
# Notebook Lenovo V330 / Intel Core i7 / 4GB RAM / 1TB DD de 14"
# 439990.00
# Notebook HP Intel core i7 / 20GB (16GB Optane + 4GB RAM) / 1TB DD / 15,6"
# 459990.00
# Notebook HP / Intel Core I5 / 20GB (16GB Optane + 4GB RAM) / 1TB DD / AMD RADEON™ 530 2GB / 14"
# 379990.00
# Notebook HP Spectre x360 13-ap0001la, Intel Core i7, Win10, 8 GB, SSD 256 GB de 13.3" FHD Touch
# 999990.00
# Notebook HP Pavilion / Ryzen 5 / 16GB RAM / 1TB HDD + 128GB SSD / 15,6" FHD
# 549990.00
# Notebook HP / Intel Pentium Gold / 4 GB RAM / 128 GB SSD de 14" HD
# 229990.00
# Notebook Dell INSPIRON 5482, Intel Core i7, Win10, 8 GB DDR4, SSD 256 GB, de 14" FHD
# 599000.00
# Notebook Gamer Asus / AMD Ryzen 5 / 512GB SSD / 8GB RAM / GTX1050 3GB / 15,6" FHD
# 529990.00
# NOTEBOOK ASUS X407UB BV169T I3 8130U
# 365500.00
# Notebook Asus X510Q I7-A12 12GBRam 1TB  Win10
# 417999.00
# Notebook Acer Aspire 5 / Intel Core i7 / 256GB SSD / 8GB RAM / 15.6" HD
# 499990.00
# Notebook Acer Aspire 5, Intel Core i7, Windows 10, 12 GB, SSD 256 GB de 15.6"
# 519990.00
# Notebook Acer Aspire 3 / AMD Ryzen 3 / 256GB SSD / 8GB RAM de 15.6" HD
# 319990.00
# Notebook Acer Aspire 5 / Intel Core i3 / 256GB SDD / 12GB RAM / de 14"
# 339990.00
# Notebook Acer Nitro 5 , Intel Core i5, Windows 10, 4 GB + 16 GB Intel Optane, HDD 1 TB de 15.6"
# 539990.00
# Notebook Acer Aspire 7, Intel Core i7, Win10, 8 GB, HDD 1 TB, TV 4 GB de 15.6" FHD
# 739000.00
# MacBook Pro Retina I5 13" 2015 Apple
# 699990.00
# Notebook Acer Aspire 3, AMD Ryzen 5, Windows 10, 12 GB, HDD 1 TB de 15.6" HD
# 349990.00
# Notebook HP / Intel Core i5 / 1TB DD / 4GB RAM / 14" HD
# 339990.00
# Notebook HP 245 G7 AMD A4-9125 FreeDOS
# 136990.00
# Notebook HP 240 G6, Intel Celeron, FreeDOS (Sin Sistema Operativo), 4 GB, HDD 500 GB de 14" HD
# 149990.00
# NOTEBOOK DELL INSPIRION 3481 I3 (FWT6G)
# 319000.00
# DELL INSPIRON 15 5575-98MH4  AMD RYZEN 8GB 1TB VIDEO RADEON
# 399000.00
# Notebook Asus / Intel Pentium Gold / 4GB RAM / 128GB SSD / 14"
# 259990.00
# Notebook Asus TUF Gaming Intel Core i7 / 1TB DD / 8GB RAM / GeForce GTX 1050 Ti (4GB) de 15,6" FHD
# 699990.00
# Notebook Asus / Intel Core i3 /  20GB (4GB RAM + 16GB Intel Optane) / 1TB DD / 15.6"
# 319990.00
# Notebook Intel Core i3 12GB RAM 256GB SSD 14'
# 379990.00
# Notebook Acer Intel Core i5 20GB (4GB RAM + 16GB Optane) 1TB DD 15,6"
# 359990.00
# Notebook Acer Aspire 3, AMD Ryzen 5, Windows 10, 8 GB, HDD 1 TB de 15.6" HD
# 349990.00
# Notebook Acer Aspire 3 A315-41-R09T, AMD RYZEN R5, Windows 10 Home, 4GB, HDD 1TB de 15,6'' HD
# 279990.00
# Notebook HP Stream 11-ah011wm, Intel Celeron, Windows 10, 4 GB, eMMc 32 GB de 11.6" - Celeste
# 139990.00
# Notebook Gamer Acer Nitro, AMD Ryzen 5, Win 10, 16 GB, 2 TB + 128 SSD, TV RX560X de 15.6"
# 484990.00
# Notebook Intel Core i5 8GB RAM- 256GB SSD 14'
# 499990.00
# Notebook Lenovo Core i3 / 4GB RAM / 1TB HDD / 14"
# 279990.00
# Notebook Lenovo 330S / Intel Core i7 / 20GB (4GB RAM + 16GB Optane) / 1TB DD / 14" HD
# 469990.00
# Notebook HP ZBook 15-G3 Workstation, Intel Core i7, Win10 Pro, 16 GB, SSD 512 GB, TV Nvidia Quadro 4 GB de 15.6" FHD
# 899000.00
# HP ZBOOK 15-G3 WORKSTATION  MOVIL 16GB 512GB SSD AMD FIREPRO2GB
# 859000.00
# Notebook HP 15-DA0076LA
# 429990.00
# Notebook HP 14-bs050
# 259990.00
# Notebook Intel Core i3 4GB RAM 256 SSD 14'
# 349990.00
# Caja Deteriorada - Notebook HP 14-cm0008la, AMD R3-2200U DC, Windows 10, Ram 8GB, DD 1TB de 14''
# 379990.00
# Notebook HP 15-cs0001la, Intel Core i5, Windows 10, 12 GBK, HDD 1 TB, Video 4 GB de 15.6"
# 539990.00
# Notebook HP Pavilion / Ryzen 5 / 12GB RAM / 1TB DD / 15,6" HD
# 399990.00
# Notebook HP AMD A4, Win10, 4 GB, HDD 500 GB de 14" HD
# 199990.00
# HP ELITEBOOK 840 G6 I5 (7LL16LT)
# 1149000.00
# 2en1 Intel Core i7 8GB RAM 256 SSD 13.3'
# 1299990.00
# NOTEBOOK DELL INSPIRON 3480 8GB - 1TB
# 443900.00
# Notebook Intel Core I7 8Gb Ram 512Gb Ssd Tv 2Gb 14'
# 899990.00
# Notebook Asus X420UA, Intel Core i7, Windows 10, 8 GB, SSD 512 GB de 14" FHD
# 639990.00
# Notebook Asus Amd A6 4gb Ram 500gb 14' Windows 10
# 209990.00
# Macbook Pro Retina 13 Inch 8Gb, 256Gb Ssd Silver
# 1690000.00
# MacBook Pro Touch Bar 13.3 I5/8GB/512SSD Space Gray
# 1599990.00
# Macbook Apple Pro 13 Space Gray (Mpxw2Ci/A)
# 1290000.00
# Notebook Acer Aspire 3, Intel Core i5, Windows 10, 4 GB Ram,16 GB optane , HDD 1 TB de 15.6"
# 399990.00
# Notebook Acer Aspire 5, Intel Core i7, Windows 10, 12 GB, SSD 512 GB de 15.6"
# 629990.00
# Notebook Acer Swift 5, Intel Core i7, Windows 10, 8 GB, SSD 512 GB de 14"
# 849990.00
# Notebook Acer Nitro 5 , Intel Core i5, Windows 10, 8 GB + 16 GB Intel Optane, HDD 1 TB de 15.6"
# 599990.00
# Notebook Acer Nitro 5 , Intel Core i5, Windows 10, 12 GB ,GTX1060  HDD 1 TB de 15.6"
# 799990.00
# MacBook Air Intel Core i5 8GB RAM - 128GB SDD 13,3'
# 719990.00
# Notebook HP 14-cf0018ca, Intel Core i5, Windows 10, 8 GB, SSD 256 GB de 14"
# 379990.00
# Notebook Hp, 14-cf0051od, Intel Core i5-8250U,  Win10,  8GB RAM, 256GB SSD de 14"
# 379990.00
# Notebook ASUS X407UB-BV168T - I7-8550U/8GB/1TB/MX110-2GB/W10H
# 449990.00
# Apple MacBook Pro 13.3" Dual-Core i5 2.5GHz 500GB (Mid 2012)
# 499990.00
# Apple MacBook Pro Retina 15.4" QuadCore i7 2.3GHz 8GB RAM, 256GB SSD NVIDIA GeForce GT 650M (Mid 2012)
# 899990.00
# Macbook Pro Retina 13.3", 2.4 Ghz Core i5, 8GB RAM.
# 799990.00
# Apple MacBook Air 11.6" 1.6GHz Core i5 (Early 2015)
# 539990.00
# Notebook Acer Aspire Nitro 5 AN515, AMD Ryzen 7 2700U, Windows 10 Home, 16GB, 1TB, TV AMD Radeon RX 560X (4GB) de 15,6'' HD
# 539990.00
# Notebook Gamer Acer AMD Ryzen 7, Win10, 16 GB, HDD 1 TB + SSD 256, TV RX560X 4 GB de 15.6" FHD
# 545990.00
# Notebook Acer SF314-56G-51FY-1 I5-8265U/8GB/512SSD/MX150 2GB/14"
# 479990.00
# Notebook Gamer Acer Nitro 5, AMD Ryzen 7, Win10, 8 GB, HDD 1 TB + SSD 128 GB, TV 4 GB de 15.6" FHD
# 539990.00
# Notebook Acer A315-21G-979M-2, AMD A-Series A9-9420e, Windows 10 Home, 12GB DDR4, 500GB, TV AMD Radeon 520 2GB GDDR5 de 15,6''
# 239990.00
# Notebook Acer Nitro 5 AN515-52-51RW, Intel® Core™ i5-8300H, Windows 10 Home, 8+16GB OPT, 1TB, TV NVIDIA® GeForce® GTX 1050  de 15,6'' FHD
# 509990.00
# Notebook Acer A315-41-R09V, AMD Ryzen™ 5-2500U, Windows 10 Home, 8GB, 1TB+128GB 15,6'' HD
# 314990.00
# Notebook Acer SF113-31-P85C, Intel® Pentium® N4200, W10, 4GB, 128GB SSD de 13,3''
# 249990.00
# Notebook Lenovo Intel Core i3, Win10, 4GB, SSD 128 GB de 14" FHD - Plateado
# 299990.00
# Notebook Lenovo 120s-11IAP Celeron N3350 32GB 2 GB de RAM Pantalla de 11.6'' W10
# 129990.00
# HP ELITEBOOK 820-G3 12.5" I5-6300U, 8GB, 256GB SSD, W10PRO, ALUMINUM
# 569000.00
# Notebook Gamer HP 15-dk0005la, Intel Core i7, Win10, 8 GB, SSD 256 GB, TV GTX 1050 4 GB de 15.6" FHD
# 679990.00
# NOTEBOOK HP 14-cd1021la PAV 2in1 i3-8145U 4GB 256GB PCIe W10
# 359990.00
# Notebook HP 245, AMD A4, Win10, 4 GB, HDD 500 GB de 14" HD
# 166990.00
# Notebook HP 240 G7 Intel Celeron N4000 4GB 500GB 14" W10h 6GJ49LT
# 199990.00
# Caja Deteriorada - Notebook HP Pavilion 15-cw0002la, AMD R5, Windows 10, 12 GB, HDD 1 TB de 15.6"
# 349990.00
# Notebook HP / Intel Pentium Gold / 256GB SSD / 8GB RAM / 14" HD
# 269990.00
# Notebook 2-en-1 Dell, AMD A6, Win10, 4 GB, eMMC 64 GB de 11.6" HD Touch - Rojo
# 219990.00
# NOTEBOOK DEL INSPIRON 3480 i5-8265U 8 GB 1TB 14 UBUNTU
# 423990.00
# Notebook Intel Core i5 8GB RAM 256GB SSD TV 2GB 14'
# 599990.00
# NOTEBOOK GAMER ACER NITRO 5 COREI5 8VAGEN. RAM 16GB 500GB SSD  NVIDIA GTX 1050 BOLSO REGALO
# 689000.00
# Notebook Gamer Acer AMD Ryzen R5 W10 16GB HDD 1 TB TV 4GB de 15.6"
# 499990.00
# Notebook Lenovo Quad Core Pentium 4GB RAM 500GB DD-Gris
# 199990.00
# Notebook Gamer HP Pavilion, Intel Core i5, Win10, 8GB, 1 TB, TV Nvidia Gtx1050 4GB de 15.6" FHD
# 579990.00
# Notebook Dell Latitude, Intel Core i5, Win8 Pro, 8 GB, HDD 500 GB de 14" HD
# 269000.00
# Notebook Acer A315-53-54LN, Intel Core i5-8250U, Windows 10 Home, 4GB (16 Optane), 1TB de 15,6''
# 349990.00
# Notebook Acer Nitro 5 AN515-52-722W, Intel Core i7, Windows 10 Home, 16GB, 1TB, TV NVIDIA GeForce GTX serie 10 de 15,6'' HD
# 674990.00
# Notebook Acer Gamer AN515-42-R5M8, AMD Ryzen 5 2500u, W10, 16GB, 1TB, RX 560X 4GB de 15,6'' FHD
# 449990.00
# Notebook Lenovo, AMD A9, Win10, 8 GB, HDD 1 TB + SSD 256 GB de 15.6" HD
# 349990.00
# Notebook Lenovo V145 amd A6/ RAM 4gb/ HDD 500GB/ WIN10/ 15,6"
# 219990.00
# Notebook Lenovo FLEX 5 15 2-IN-1, Intel Core i7, Win10, 8 GB, SSD 256GB M.2, TV 2 GB de 15.6" FHD
# 619000.00
# Notebook Lenovo Yoga, Intel Pentium, Win10, 4 GB, SSD 128 GB de 11.6" HD Touchscreen
# 299990.00
# Notebook HP 15-db0010la, AMD A9, Win10, 4 GB, HDD 1 TB, TV 2 GB de 15.6" HD
# 279990.00
# NOTEBOOK HP 240 G7 CELERON N4000 (6FU25LT)
# 270000.00
# Notebook HP i3 8va Gen - 20Gb (4+16 Optane) 1Tb HDD FLASH / Laptop 15.6"
# 489844.53
# Hp 240 G6 Intel Celeron N4000 4Gb 500Gb Freedos (3Xu15Lt)
# 190000.00
# Notebook Asus Vivobook, Intel Core i5, Win10, 8 GB, HDD 1 TB de 15.6" HD Touch
# 499000.00
# Caja Deteriorada - Notebook Asus X407MA-BV069T Intel Celeron Windows 10 RAM 4 GB 14"
# 199990.00
# Notebook Asus Intel Core i3, Win10, 4 GB + 16 GB Optane, HDD 1 TB de 15.6" HD
# 329990.00
# Asus Notebook Intel Core i7 8GB RAM- 1TB TV 2GB 15.6'
# 549990.00
# Notebook Acer Aspire 3, AMD Ryzen 5, Windows 10, 4 GB, HDD 1 TB de 15.6" HD
# 309990.00
# Acer Notebook Intel Core i7 12GB RAM 512GB SSD 15.6'
# 689990.00
# Notebook Acer Aspire 5, Intel Core i7, Windows 10, 4 GB, SSD 512 GB de 15.6"
# 539990.00
# Notebook Gamer Msi GL63 8CR-664, Intel Core i5, Win10, 8GB RAM, 1TB, TV Nvidia 2GB de 15.6" FHD
# 599990.00
# Notebook HP Stream Pro G2, Intel Celeron, Win10, 4 GB, SSD 64 GB de 11.6"
# 159990.00
# Notebook Asus VivoBook X555QG-DM341T AMD A12/ 8GB RAM /TB HDD/TV 2G / WIN10
# 369990.00
# Apple MacBook Pro 13.3" Dual-Core i5 2.5GHz 1TB SSD (Mid 2012)
# 654990.00
# Notebook Acer A315-41-R8J9 (Ryzen 5-3500U/4GB/1TB HDD/15.6”/W10)
# 284990.00
# Notebook Acer Aspire ES1-433G-38J2, Intel Core i3 7100U, Windows 10 Home, 4GB DDR4, HDD 500GB, TV NVIDIA GeForce 920MX (2GB) de 14.0" HD
# 274990.00
# Notebook Acer A315-53-386P, Intel i3 8130U, Windows 10 Home, 16GB, 1TB de 15,6'' UHD
# 309990.00
# Notebook Acer A515-51G-83QA Intel Core i7/ Windows 10 /RAM 4+16GB/15.6"-Negro
# 399990.00
# Notebok Acer A315-53-P3PQ-1 Pentium 8GB 500GB 15.6"
# 214990.00
# Notebook Acer A515-52-5036 I5-8265U/4GB(16GB optane)/2TB/W10H
# 384990.00
# Notebook Acer Aspire 3 A314-31-P6AB,  Intel Pentium N4200, Windows 10 Home, 4GB, 500GB de 14'' HD
# 189990.00
# Notebook Acer Aspire 5 A515-52-76SR-1, i7-8565U, Ram 8GB, SSD 256GB, 15.6", W10
# 459990.00
# Notebook acer SF314-54-51J6-1 i5 8250U/8GB/256SSD/14"
# 420990.00
# Notebook Acer Aspire 3 A315-21-90K2, A9-9420e, 4 GB RAM, 500GB
# 209990.00
# Notebook Acer  A315-21-90K2 AMD A9-9420 /4GB/500GB/AMD Radeon 520 (2GB)
# 204990.00
# Notebook Acer Aspire 3, Intel Pentiun, Windows 10, 4 GB, HDD 1TB de 14"
# 189990.00
# 13" 15" Air Pro Funda, Cubierta Dura Case Carcasa Para 11" 12" Macbook Retina Touchbar, Crystal-Rosa Claro
# 13759.00
# Carcasa Plástica para Raspberry Pi 4 modelo B con Ventilador
# 7830.00
# Bolso Notebook de 13.3″ Charlotte Purple - KINGSONS
# 48990.00
# Mesa plegable para notebooks con ventiladores e-table
# 12990.00
# 13" 15" Air Pro Funda, Cubierta Dura Case Carcasa Para 11" 12" Macbook Retina Touchbar, Mate-Verde Claro
# 14479.00
# Funda para Laptop Macbook 11 12 13 15 Carcasa Dura- Multicolor
# 15379.00
# Funda para Laptop Macbook 11 12 13 15 Carcasa Dura- Naranja
# 13759.00
# EY Extractor de aire de bajo ruido Ventilador de refrigeración Radiador Extractor de CPU de escape-Negro
# 13990.00
# Usb led Light Portable Flexible Yellow
# 690.00
# Lámpara Flexible USB Led para Notebook
# 280.00
# Notebook Acer Travelmate, Intel Core i7, Windows 10, 12 GB, HDD 1 TB de 14"
# 579990.00
# CABLE USB TIPO C a HDMI 1,5MTS UGREEN
# 27990.00
# Toshiba Disco Duro Interno 2.5" 500GB 5400rpm PC-L200
# 47990.00
# Raspberry Pi 4 Modelo B / 2GB RAM
# 55990.00
# EH 10LED Lámpara de luz portátil USB para  portátil PC de escritorio
# 6390.00
# Notebook Gamer MSI GL73 Intel Core i7, Win10, 8 GB, SSD 256 GB, TV 4 GB de 17.3" FHD
# 839000.00
# Notebook Gamer MSI P65 Creator, Intel Core i7, Win10, 32 GB, SSD 1 TB, TV Nvidia GeForce RTX 6 GB de 15.6" UHD 4K
# 2199000.00
# Notebook Lenovo Ideapad 330-14IGM Pentium N5000, 4GB DDR4, 500GB HDD,14”, Win10
# 359990.00
# NOTEBOOK LENOVO V130-14IKB I3-6006U 4GB 500GB 14" W10 HOME
# 319000.00
# WORKSTATION MOBILE P52 I7 (20MAS3FU00)
# 1750000.00
# NOTEBOOK LENOVO V145 AMD 4GB (81MS000UCL)
# 209990.00
# Notebook Lenovo AMD Ryzen 5 / 8GB RAM - 1TB HDD / Laptop 15,6" - Vega 8
# 575742.59
# Notebook AMD RYZEN R5 4GB RAM- 128GB SSD 14'
# 369990.00
# Notebook Intel Core I7 8Gb Ram-1Tb Dd 14'
# 639990.00
# LENOVO - NOTEBOOK T480S I7-8550U 8GB 512GB SSD 14" W10 PRO (20L8A00CCL)
# 1704990.00
# Notebook Lenovo 330S Intel Core i3 / 1TB DD / 20GB RAM (16GB Optane + 4GB) / 14"
# 329990.00
# Notebook 2-en-1 Lenovo, AMD R5, Win10, 8 GB, SSD 256 GB de 14"
# 449990.00
# Notebook Lenovo Ideapad, Intel Core i5, Win10, 8 GB, SSD 128 GB de 14" FHD
# 649990.00
# Notebook Lenovo Ideapad 330S, AMD Ryzen 5, Win10, 8 GB, HDD 1 TB de 15.6" FHD
# 349000.00
# Notebook Gamer Lenovo Legion, Intel Core i5, Win10, 8 GB, SSD 1 TB, TV GTX 1650 4 GB de 15.6" FHD
# 849990.00
# Notebook Intel Core i7 SSD 128GB 12GB 15.6'
# 699990.00
# LENOVO - NOTEBOOK V330 I5-8250U 4GB 1TB 14" W10 HOME (81B0009RCL)
# 467990.00
# NOTEBOOK LENOVO L490 I5 (20Q6S10900)
# 1000000.00
# Notebook Lenovo V130-14IGM, Intel Celeron, Windows 10, 4 GB, HDD 500 GB de 14" HD
# 249000.00
# Notebook Lenovo V330, Intel Core i7, Windows 10 Pro, 20 GB: 4 GB + 16 GB Optane, HDD 1 TB de 14" HD
# 569990.00
# Notebook Lenovo Ideapad, AMD Ryzen 7, Win10, 8 GB, HDD 1 TB de 15.6" HD
# 429990.00
# Cartera Porta Notebook de 13.3″ Classic Fun - KINGSONS
# 41990.00
# Bolso para Laptop de 14,1″ Lady Pink- KINGSONS
# 32990.00
# Cartera Para Notebook de 15.6″ Charol Beige
# 39990.00
# Mochila Porta Notebook Executive Line 15.6" - Kingsons
# 52990.00
# Maletín para Notebook Professional Young Red Red 14,1" Kingsons
# 49990.00
# Bolso Porta Notebook Elite 14,1" Kingsons
# 59990.00
# Bolso Porta Notebook de 13.3″ Charlotte Grey
# 48990.00
# Mochila Frosted Ice 15,6″ Kingsons
# 32990.00
# Funda para Notebook Black 14,1" Kingsons
# 20990.00
# Cartera Notebook Black & White 13.3" Kingsons
# 41990.00
# Mochila Frosted Carbono 15,6″ Kingsons
# 38990.00
# Notebook HP 13-ak0001la
# 1399990.00
# Notebook HP  250 G6, Intel Core i3, Windows 10 Home, 8 GB, 1 TB de 15.6”
# 429990.00

# %%
import pandas as pd
pd.DataFrame(productos)
# Out:
#           price                                              title
# 0     319990.00  Notebook 2-en-1 HP X360 14-cd0003la, Intel Cor...
# 1     139990.00  Notebook Lenovo V145, AMD A4, FreeDOS (Sin Sis...
# 2     179990.00  Notebook Lenovo V130-14IGM, Intel Celeron, Win...
# 3     899000.00  Notebook MSI GL73, Intel Core i7 9ª Gen, Win10...
# 4    2899990.00  Notebook ZenBook Pro Duo Intel Core i9 32GB - ...
# 5     163990.00  NOTEBOOK LENOVO V145-15AST AMD A6-9225 4GB 500...
# 6     439990.00  Notebook Lenovo V330 / Intel Core i7 / 4GB RAM...
# 7     459990.00  Notebook HP Intel core i7 / 20GB (16GB Optane ...
# 8     379990.00  Notebook HP / Intel Core I5 / 20GB (16GB Optan...
# 9     999990.00  Notebook HP Spectre x360 13-ap0001la, Intel Co...
# 10    549990.00  Notebook HP Pavilion / Ryzen 5 / 16GB RAM / 1T...
# 11    229990.00  Notebook HP / Intel Pentium Gold / 4 GB RAM / ...
# 12    599000.00  Notebook Dell INSPIRON 5482, Intel Core i7, Wi...
# 13    529990.00  Notebook Gamer Asus / AMD Ryzen 5 / 512GB SSD ...
# 14    365500.00               NOTEBOOK ASUS X407UB BV169T I3 8130U
# 15    417999.00      Notebook Asus X510Q I7-A12 12GBRam 1TB  Win10
# 16    499990.00  Notebook Acer Aspire 5 / Intel Core i7 / 256GB...
# 17    519990.00  Notebook Acer Aspire 5, Intel Core i7, Windows...
# 18    319990.00  Notebook Acer Aspire 3 / AMD Ryzen 3 / 256GB S...
# 19    339990.00  Notebook Acer Aspire 5 / Intel Core i3 / 256GB...
# 20    539990.00  Notebook Acer Nitro 5 , Intel Core i5, Windows...
# 21    739000.00  Notebook Acer Aspire 7, Intel Core i7, Win10, ...
# 22    699990.00               MacBook Pro Retina I5 13" 2015 Apple
# 23    349990.00  Notebook Acer Aspire 3, AMD Ryzen 5, Windows 1...
# 24    339990.00  Notebook HP / Intel Core i5 / 1TB DD / 4GB RAM...
# 25    136990.00             Notebook HP 245 G7 AMD A4-9125 FreeDOS
# 26    149990.00  Notebook HP 240 G6, Intel Celeron, FreeDOS (Si...
# 27    319000.00            NOTEBOOK DELL INSPIRION 3481 I3 (FWT6G)
# 28    399000.00  DELL INSPIRON 15 5575-98MH4  AMD RYZEN 8GB 1TB...
# 29    259990.00  Notebook Asus / Intel Pentium Gold / 4GB RAM /...
# ..          ...                                                ...
# 150  1750000.00             WORKSTATION MOBILE P52 I7 (20MAS3FU00)
# 151   209990.00          NOTEBOOK LENOVO V145 AMD 4GB (81MS000UCL)
# 152   575742.59  Notebook Lenovo AMD Ryzen 5 / 8GB RAM - 1TB HD...
# 153   369990.00       Notebook AMD RYZEN R5 4GB RAM- 128GB SSD 14'
# 154   639990.00          Notebook Intel Core I7 8Gb Ram-1Tb Dd 14'
# 155  1704990.00  LENOVO - NOTEBOOK T480S I7-8550U 8GB 512GB SSD...
# 156   329990.00  Notebook Lenovo 330S Intel Core i3 / 1TB DD / ...
# 157   449990.00  Notebook 2-en-1 Lenovo, AMD R5, Win10, 8 GB, S...
# 158   649990.00  Notebook Lenovo Ideapad, Intel Core i5, Win10,...
# 159   349000.00  Notebook Lenovo Ideapad 330S, AMD Ryzen 5, Win...
# 160   849990.00  Notebook Gamer Lenovo Legion, Intel Core i5, W...
# 161   699990.00        Notebook Intel Core i7 SSD 128GB 12GB 15.6'
# 162   467990.00  LENOVO - NOTEBOOK V330 I5-8250U 4GB 1TB 14" W1...
# 163  1000000.00               NOTEBOOK LENOVO L490 I5 (20Q6S10900)
# 164   249000.00  Notebook Lenovo V130-14IGM, Intel Celeron, Win...
# 165   569990.00  Notebook Lenovo V330, Intel Core i7, Windows 1...
# 166   429990.00  Notebook Lenovo Ideapad, AMD Ryzen 7, Win10, 8...
# 167    41990.00  Cartera Porta Notebook de 13.3″ Classic Fun - ...
# 168    32990.00     Bolso para Laptop de 14,1″ Lady Pink- KINGSONS
# 169    39990.00        Cartera Para Notebook de 15.6″ Charol Beige
# 170    52990.00  Mochila Porta Notebook Executive Line 15.6" - ...
# 171    49990.00  Maletín para Notebook Professional Young Red R...
# 172    59990.00          Bolso Porta Notebook Elite 14,1" Kingsons
# 173    48990.00       Bolso Porta Notebook de 13.3″ Charlotte Grey
# 174    32990.00                 Mochila Frosted Ice 15,6″ Kingsons
# 175    20990.00           Funda para Notebook Black 14,1" Kingsons
# 176    41990.00      Cartera Notebook Black & White 13.3" Kingsons
# 177    38990.00             Mochila Frosted Carbono 15,6″ Kingsons
# 178  1399990.00                            Notebook HP 13-ak0001la
# 179   429990.00  Notebook HP  250 G6, Intel Core i3, Windows 10...
#
# [180 rows x 2 columns]

# %% [markdown]
# ### Ejercicio 4

# %% [markdown]
# Extraer información sobre "Magister en data science" en Google utilizando Selenium

# %%
# !pip install -U selenium
# !pip install webdriver-manager
# Out:
# Collecting selenium
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 1.0MB/s ta 0:00:01
# Collecting urllib3 (from selenium)
#   Downloading https://files.pythonhosted.org/packages/b4/40/a9837291310ee1ccc242ceb6ebfd9eb21539649f193a7c8c86ba15b98539/urllib3-1.25.7-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 3.8MB/s ta 0:00:01
# Installing collected packages: urllib3, selenium
# Successfully installed selenium-3.141.0 urllib3-1.25.7
# Collecting webdriver-manager
#   Downloading https://files.pythonhosted.org/packages/c2/f6/bd9d73991fd8d1b488aefa4b55711af670e938a9b8549ffd8ecc42780069/webdriver_manager-2.3.0-py2.py3-none-any.whl
# Collecting requests (from webdriver-manager)
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#     100% |████████████████████████████████| 61kB 2.0MB/s ta 0:00:011
# Collecting configparser (from webdriver-manager)
#   Downloading https://files.pythonhosted.org/packages/7a/2a/95ed0501cf5d8709490b1d3a3f9b5cf340da6c433f896bbe9ce08dbe6785/configparser-4.0.2-py2.py3-none-any.whl
# Collecting crayons (from webdriver-manager)
#   Downloading https://files.pythonhosted.org/packages/f8/64/ab71c69db049a5f404f1f2c7627578f4b59aca55e6ad9d939721ce6466dd/crayons-0.3.0-py2.py3-none-any.whl
# Collecting chardet<3.1.0,>=3.0.2 (from requests->webdriver-manager)
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 4.0MB/s ta 0:00:011
# Collecting certifi>=2017.4.17 (from requests->webdriver-manager)
#   Downloading https://files.pythonhosted.org/packages/b9/63/df50cac98ea0d5b006c55a399c3bf1db9da7b5a24de7890bc9cfd5dd9e99/certifi-2019.11.28-py2.py3-none-any.whl (156kB)
#     100% |████████████████████████████████| 163kB 3.8MB/s ta 0:00:01
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests->webdriver-manager)
#   Using cached https://files.pythonhosted.org/packages/b4/40/a9837291310ee1ccc242ceb6ebfd9eb21539649f193a7c8c86ba15b98539/urllib3-1.25.7-py2.py3-none-any.whl
# Collecting idna<2.9,>=2.5 (from requests->webdriver-manager)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 4.8MB/s ta 0:00:011
# Collecting colorama (from crayons->webdriver-manager)
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Installing collected packages: chardet, certifi, urllib3, idna, requests, configparser, colorama, crayons, webdriver-manager
# Successfully installed certifi-2019.11.28 chardet-3.0.4 colorama-0.4.3 configparser-4.0.2 crayons-0.3.0 idna-2.8 requests-2.22.0 urllib3-1.25.7 webdriver-manager-2.3.0

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(3)

driver.get('https://google.cl')

elem = driver.find_element_by_name('q')
elem.clear()
elem.send_keys("Magister en data science")
elem.send_keys(Keys.RETURN)

elems = driver.find_elements_by_css_selector('div.g')
for e in elems:
    try:
        print(e.find_element_by_tag_name('h3').text)
        print(e.find_element_by_tag_name('cite').text)
        print()
    except:
        print("No encontré elementos")
        print()
    
driver.close()
# Out:
# Trying to download new driver from http://chromedriver.storage.googleapis.com/79.0.3945.36/chromedriver_linux64.zip
# Unpack archive /home/caracena/.wdm/drivers/chromedriver/79.0.3945.36/linux64/chromedriver.zip
# Magíster en Data Science - Universidad Adolfo Ibáñez
# https://www.uai.cl › magister › magister-en-data-science
#
# Magíster en Data Science - Ingeniería UAI
# https://ingenieria.uai.cl › magister-en-data-science
#
# Magíster en Data Science - Facultad de Ingeniería
# https://ingenieria.udd.cl › magister-en-data-science
#
# Data Analytics Certificate Universidad de Chile & MIT Sloan ...
# www.postgradouchile.cl › index.php › mit_data_analyti...
#
# Diplomado en Data Science - Educación Continua UC
# educacioncontinua.uc.cl › 36756-ficha-diplomado-en-d...
#
# Propuesta de Magíster en Data Science es presentada en ...
# ingenieria.uchile.cl › noticias › propuesta-de-magister-e...
#
# Master en Data Science & Business Intelligence Online - IEBS
# https://www.iebschool.com › Programas
#
# Diplomados Data Science en Chile - GitHub
# https://github.com › robsalasco › data_science_chile
#
# ▷Máster en Data Science: Universidad de Alcalá
# https://www.master-data-scientist.com
#
# Best 23 Schools with Data Science Master's Programs
# https://www.mastersindatascience.org › schools › 23-great-schools-with-ma...
#
# No encontré elementos

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.implicitly_wait(3)

driver.get('https://es.wikipedia.org') 

elem = driver.find_element_by_name('search')
elem.clear()

#b. Ingresar en el input de búsqueda el string “paises por superficie” y presionar enter.
elem.send_keys('paises por superficie')
elem.send_keys(Keys.RETURN)

columna    = [] 
territorio = [] 
superficie = [] 

h = driver.find_elements_by_xpath("//tr/th")
for i in h:
    columna.append(i.text)

    
elemento_1 = driver.find_elements_by_xpath("//tr/td[2]")
for e in elemento_1:
    territorio.append(e.text)
    
elemento_2 = driver.find_elements_by_xpath("//tr/td[3]")

#d. Extraer la lista de países y territorios con su superficie desde la página de resultados
#(no incluir Planeta Tierra, Océanos y Tierras emergidas). (2puntos)

for a in elemento_2:
    superficie.append(a.text)

#Cierro el navegador
driver.close()
# Out:
# Looking for [chromedriver 79.0.3945.36 linux64] driver in cache
# File found in cache by path [/home/caracena/.wdm/drivers/chromedriver/79.0.3945.36/linux64/chromedriver]

# %%
territorio
# Out:
# ['Planeta Tierra',
#  'Océanos',
#  'Tierras emergidas',
#  ' Rusia',
#  ' Antártida',
#  ' Canadá',
#  ' China',
#  ' Estados Unidos',
#  ' Brasil',
#  ' Australia',
#  ' India',
#  ' Argentina',
#  ' Kazajistán',
#  ' Argelia',
#  ' República Democrática del Congo',
#  ' Groenlandia',
#  ' Arabia Saudita',
#  ' México',
#  ' Indonesia',
#  ' Sudán',
#  ' Libia',
#  ' Irán',
#  ' Mongolia',
#  ' Perú',
#  ' Chad',
#  ' Níger',
#  ' Angola',
#  ' Malí',
#  ' Sudáfrica',
#  ' Colombia',
#  ' Etiopía',
#  ' Bolivia',
#  ' Mauritania',
#  ' Egipto',
#  ' Tanzania',
#  ' Nigeria',
#  ' Venezuela',
#  ' Namibia',
#  ' Mozambique',
#  ' Pakistán',
#  ' Turquía',
#  ' Chile',
#  ' Zambia',
#  ' Birmania',
#  ' Afganistán',
#  ' Sudán del Sur',
#  ' Francia',
#  ' Somalia',
#  ' República Centroafricana',
#  ' Ucrania',
#  ' Madagascar',
#  ' Botsuana',
#  ' Kenia',
#  ' Yemen',
#  ' Tailandia',
#  ' España',
#  ' Turkmenistán',
#  ' Camerún',
#  ' Papúa Nueva Guinea',
#  ' Suecia',
#  ' Uzbekistán',
#  ' Marruecos',
#  ' Irak',
#  ' Paraguay',
#  ' Zimbabue',
#  ' Japón',
#  ' Alemania',
#  ' República del Congo',
#  ' Finlandia',
#  ' Vietnam',
#  ' Malasia',
#  ' Noruega',
#  ' Costa de Marfil',
#  ' Polonia',
#  ' Omán',
#  ' Italia',
#  ' Filipinas',
#  ' Ecuador',
#  ' Burkina Faso',
#  ' Nueva Zelanda',
#  ' Gabón',
#  ' Sahara Occidental',
#  ' Guinea',
#  ' Reino Unido',
#  ' Uganda',
#  ' Ghana',
#  ' Rumania',
#  ' Laos',
#  ' Guyana',
#  ' Bielorrusia',
#  ' Kirguistán',
#  ' Senegal',
#  ' Siria',
#  ' Camboya',
#  ' Uruguay',
#  ' Surinam',
#  ' Túnez',
#  ' Nepal',
#  ' Bangladés',
#  ' Tayikistán',
#  ' Grecia',
#  ' Nicaragua',
#  ' Corea del Norte',
#  ' Malaui',
#  ' Eritrea',
#  ' Benín',
#  ' Honduras',
#  ' Liberia',
#  ' Bulgaria',
#  ' Cuba',
#  ' Guatemala',
#  ' Islandia',
#  ' Corea del Sur',
#  ' Hungría',
#  ' Portugal',
#  ' Jordania',
#  ' Azerbaiyán',
#  ' Austria',
#  ' Emiratos Árabes Unidos',
#  ' República Checa',
#  ' Serbia',
#  ' Panamá',
#  ' Sierra Leona',
#  ' Irlanda',
#  ' Georgia',
#  ' Sri Lanka',
#  ' Lituania',
#  ' Letonia',
#  ' Svalbard',
#  ' Togo',
#  ' Croacia',
#  ' Bosnia y Herzegovina',
#  ' Costa Rica',
#  ' Eslovaquia',
#  ' República Dominicana',
#  ' Estonia',
#  ' Dinamarca',
#  ' Países Bajos',
#  ' Suiza',
#  ' Bután',
#  ' Guinea-Bisáu',
#  ' República de China',
#  ' Moldavia',
#  ' Bélgica',
#  ' Lesoto',
#  ' Armenia',
#  ' Islas Salomón',
#  ' Albania',
#  ' Guinea Ecuatorial',
#  ' Burundi',
#  ' Haití',
#  ' Ruanda',
#  ' Macedonia del Norte',
#  ' Yibuti',
#  ' Belice',
#  ' El Salvador',
#  ' Israel',
#  ' Eslovenia',
#  ' Nueva Caledonia',
#  ' Fiyi',
#  ' Kuwait',
#  ' Suazilandia',
#  ' Timor Oriental',
#  ' Bahamas',
#  ' Montenegro',
#  ' Vanuatu',
#  ' Islas Malvinas',
#  ' Catar',
#  ' Gambia',
#  ' Jamaica',
#  ' Kosovo',
#  ' Líbano',
#  ' Chipre',
#  ' Puerto Rico',
#  ' Tierras Australes y Antárticas Francesas',
#  ' Palestina',
#  ' Brunéi',
#  ' Trinidad y Tobago',
#  ' Polinesia Francesa',
#  ' Cabo Verde',
#  ' Islas Georgias del Sur y Sandwich del Sur',
#  ' Samoa',
#  ' Luxemburgo',
#  ' Comoras',
#  ' Mauricio',
#  ' Islas Feroe',
#  ' Hong Kong',
#  ' Santo Tomé y Príncipe',
#  ' Islas Turcas y Caicos',
#  ' Kiribati',
#  ' Baréin',
#  ' Dominica',
#  ' Tonga',
#  ' Estados Federados de Micronesia',
#  ' Singapur',
#  ' Santa Lucía',
#  ' Isla de Man',
#  ' Guam',
#  ' Andorra',
#  ' Islas Marianas del Norte',
#  ' Palaos',
#  ' Seychelles',
#  ' Curazao',
#  ' Antigua y Barbuda',
#  ' Barbados',
#  ' Islas Heard y McDonald',
#  ' San Vicente y las Granadinas',
#  ' Jan Mayen',
#  ' Islas Vírgenes de los Estados Unidos',
#  ' Granada',
#  ' Malta',
#  ' Santa Elena, Ascensión y Tristán de Acuña',
#  ' Maldivas',
#  ' Islas Caimán',
#  ' San Cristóbal y Nieves',
#  ' Niue',
#  ' Acrotiri y Dhekelia',
#  ' San Pedro y Miquelón',
#  ' Islas Cook',
#  ' Samoa Americana',
#  ' Islas Marshall',
#  ' Aruba',
#  ' Liechtenstein',
#  ' Islas Vírgenes Británicas',
#  ' Wallis y Futuna',
#  ' Isla de Navidad',
#  ' Jersey',
#  ' Montserrat',
#  ' Anguila',
#  ' Guernsey',
#  ' San Marino',
#  ' Territorio Británico del Océano Índico',
#  ' San Martín',
#  ' Bermudas',
#  ' Isla Bouvet',
#  ' Islas Pitcairn',
#  ' Isla Norfolk',
#  'Islas ultramarinas de los Estados Unidos',
#  ' San Martín',
#  ' Macao',
#  ' Tuvalu',
#  ' Nauru',
#  ' San Bartolomé',
#  ' Islas Cocos',
#  ' Tokelau',
#  ' Gibraltar',
#  'Isla Clipperton',
#  'Islas Ashmore y Cartier',
#  'Islas Spratly',
#  'Islas del Mar del Coral',
#  ' Mónaco',
#  ' Ciudad del Vaticano']

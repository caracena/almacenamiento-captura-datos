# %% [markdown]
# ### Ejercicio 1

# %%
with open('data/names.txt') as f:
    lines = f.readlines()
    with open('data/names.csv', 'w') as fw:
        fw.write('nombre , apellido\n')
        for l in lines:
            ##nombre, apellido = l.split()
            ##fw.write('{},{}\n'.format(nombre, apellido))
            fw.write(','.join(l.split())+ '\n')

# %% [markdown]
# ### Ejercicio 2

# %%
with open('data/el_quijote.txt', 'r') as f:
    content = f.read()
    
words = content.split(" ")
counter = {}

for w in words:
    if w in counter:
        counter[w] += 1
    else:
        counter[w] = 0

sorted_counter = sorted(counter, key=counter.get, reverse=True)
for w in sorted_counter[:10]:
    print(w, counter[w])
# Out:
# que 10305
# de 8916
# y 8011
# la 4932
# a 4712
# en 3864
# el 3712
# no 2776
# se 2379
# los 2115

# %%
# !pip install nltk

# %%
from nltk.corpus import stopwords 
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.tokenize import word_tokenize, regexp_tokenize

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('perluniprops')
nltk.download('nonbreaking_prefixes')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/caracena/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/caracena/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /home/caracena/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/caracena/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# True

# %%
## defecto para ingles
word_tokens = word_tokenize(content.lower())
len(word_tokens)
# Out:
# 213214

# %%
## no funciona bien con español, ya que no incluye acentos ni ñ
word_tokens = regexp_tokenize(content.lower(), pattern='\w+') 
len(word_tokens)
# Out:
# 201202

# %%
## mejor para español pero contiene caracteres como punto, comas, etc..
toktok = ToktokTokenizer()
word_tokens = toktok.tokenize(content.lower()) 
len(word_tokens)
# Out:
# 210818

# %%
stop_words = list(stopwords.words('spanish')) 
stop_words += [',', '.', ':', ';'] ## agregamos mas stopwords
len(stop_words)
# Out:
# 317

# %%
filtered_words =[w for w in word_tokens if not w in stop_words ] 
len(filtered_words)
# Out:
# 96107

# %%
from collections import Counter
counter = Counter(filtered_words)
counter.most_common(10)
# Out:
# [('don', 1070),
#  ('si', 970),
#  ('más', 959),
#  ('tan', 758),
#  ('él', 734),
#  ('quijote', 670),
#  ('había', 669),
#  ('dijo', 653),
#  ('sancho', 583),
#  ('así', 540)]

# %% [markdown]
# ### Ejercicio 3

# %%
import csv

with open('data/data-text.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row[0], row[1])
        break
# Out:
# Indicator PUBLISH STATES

# %%
import pandas as pd
df = pd.read_csv('data/data-text.csv')
df
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
#                  WHO region World Bank income group               Country  \
# 0                    Europe             High-income               Andorra
# 1                    Europe             High-income               Andorra
# 2                    Europe             High-income               Andorra
# 3                    Europe             High-income               Andorra
# 4     Eastern Mediterranean             High-income  United Arab Emirates
# ...                     ...                     ...                   ...
# 4651        Western Pacific     Lower-middle-income                 Samoa
# 4652  Eastern Mediterranean              Low-income                 Yemen
# 4653                 Africa     Upper-middle-income          South Africa
# 4654                 Africa              Low-income                Zambia
# 4655                 Africa              Low-income              Zimbabwe
#
#              Sex  Display Value  Numeric  Low  High  Comments
# 0     Both sexes             77     77.0  NaN   NaN       NaN
# 1     Both sexes             80     80.0  NaN   NaN       NaN
# 2         Female             28     28.0  NaN   NaN       NaN
# 3     Both sexes             23     23.0  NaN   NaN       NaN
# 4         Female             78     78.0  NaN   NaN       NaN
# ...          ...            ...      ...  ...   ...       ...
# 4651      Female             66     66.0  NaN   NaN       NaN
# 4652  Both sexes             54     54.0  NaN   NaN       NaN
# 4653        Male             49     49.0  NaN   NaN       NaN
# 4654  Both sexes             36     36.0  NaN   NaN       NaN
# 4655      Female             51     51.0  NaN   NaN       NaN
#
# [4656 rows x 12 columns]

# %%
df.to_csv('data/data-text-copy.csv')

# %% [markdown]
# ### Ejercicio 4

# %%
import json

with open('data/data-text.json') as f:
    content = f.read()
    data = json.loads(content)

for item in data:
    print(item)
    break
# Out:
# {'Indicator': 'Life expectancy at birth (years)', 'PUBLISH STATES': 'Published', 'Year': 1990, 'WHO region': 'Europe', 'World Bank income group': 'High-income', 'Country': 'Andorra', 'Sex': 'Both sexes', 'Display Value': 77, 'Numeric': 77.0, 'Low': '', 'High': '', 'Comments': ''}

# %%
with open('file.json', 'w') as f:
    json.dump(data, f)

# %%
df = pd.read_json('data/data-text.json')
df
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
#                  WHO region World Bank income group               Country  \
# 0                    Europe             High-income               Andorra
# 1                    Europe             High-income               Andorra
# 2                    Europe             High-income               Andorra
# 3                    Europe             High-income               Andorra
# 4     Eastern Mediterranean             High-income  United Arab Emirates
# ...                     ...                     ...                   ...
# 4651        Western Pacific     Lower-middle-income                 Samoa
# 4652  Eastern Mediterranean              Low-income                 Yemen
# 4653                 Africa     Upper-middle-income          South Africa
# 4654                 Africa              Low-income                Zambia
# 4655                 Africa              Low-income              Zimbabwe
#
#              Sex  Display Value  Numeric Low High Comments
# 0     Both sexes             77       77
# 1     Both sexes             80       80
# 2         Female             28       28
# 3     Both sexes             23       23
# 4         Female             78       78
# ...          ...            ...      ...  ..  ...      ...
# 4651      Female             66       66
# 4652  Both sexes             54       54
# 4653        Male             49       49
# 4654  Both sexes             36       36
# 4655      Female             51       51
#
# [4656 rows x 12 columns]

# %%
df.to_json('data/data-text-copy.json')

# %% [markdown]
# ### Ejercicio 5

# %%
# !pip install xlrd

# %%
import xlrd
book = xlrd.open_workbook("data/SOWC 2014 Stat Tables_Table 9.xlsx")

# sheet = book.sheet_by_name("Table 9 ")
sheet = book.sheet_by_index(1)

print(sheet.name)
print(sheet.nrows)
print(sheet.ncols)
# Out:
# Table 9
# 303
# 44

# %%
df = pd.DataFrame(columns = ['Name', 'child_labor_total', 'child_labor_male','child_labor_female', 
                             'child_marriage_married_by_15', 'child_marriage_married_by_18']) 
for i in range(14, 211):

    # Start at 14th row, because that is where the countries begin
    row = sheet.row_values(i)
    
    df = df.append({'Name' : row[1], 'child_labor_total' : row[4], 'child_labor_male' : row[6],
                   'child_labor_female': row[8], 'child_marriage_married_by_15': row[10],
                   'child_marriage_married_by_18': row[12]}, ignore_index=True) 

    if row[1] == "Zimbabwe":
        break

# %%
df
# Out:
#                                    Name child_labor_total child_labor_male  \
# 0                           Afghanistan              10.3               11
# 1                               Albania                12             14.4
# 2                               Algeria               4.7              5.5
# 3                               Andorra                –                 –
# 4                                Angola              23.5             22.1
# ..                                  ...               ...              ...
# 192  Venezuela (Bolivarian Republic of)               7.7              9.2
# 193                            Viet Nam               6.9              6.5
# 194                               Yemen              22.7             21.1
# 195                              Zambia              40.6             41.6
# 196                            Zimbabwe                 –                –
#
#     child_labor_female child_marriage_married_by_15  \
# 0                  9.6                           15
# 1                  9.4                          0.2
# 2                  3.9                          0.1
# 3                    –                            –
# 4                 24.8                            –
# ..                 ...                          ...
# 192                6.2                            –
# 193                7.4                          0.5
# 194               24.4                           12
# 195               39.5                          8.5
# 196                  –                          3.9
#
#     child_marriage_married_by_18
# 0                           40.4
# 1                            9.6
# 2                            1.8
# 3                              –
# 4                              –
# ..                           ...
# 192                            –
# 193                          9.3
# 194                         32.3
# 195                         41.6
# 196                         30.5
#
# [197 rows x 6 columns]

# %%
## usando pandas

# %%
df = pd.read_excel("data/SOWC 2014 Stat Tables_Table 9.xlsx", sheet_name=1, header=None)

# %%
df
# Out:
#      0                          1                                  2   \
# 0   NaN  TABLE 9. CHILD PROTECTION                                NaN
# 1   NaN                        NaN  TABLEAU 9. PROTECTION DE L’ENFANT
# 2   NaN                        NaN                                NaN
# 3   NaN                        NaN                                NaN
# 4   NaN        Countries and areas                                NaN
# ..   ..                        ...                                ...
# 298 NaN                        NaN                                NaN
# 299 NaN                        NaN                                NaN
# 300 NaN                        NaN                                NaN
# 301 NaN                        NaN                                NaN
# 302 NaN                        NaN                                NaN
#
#                                                     3   \
# 0                                                  NaN
# 1                                                  NaN
# 2                         TABLA 9. PROTECCIÓN INFANTIL
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 298  Matrimonio precoz – MICS, DHS y otras encuesta...
# 299  Inscripción del nacimiento – MICS, DHS, otras ...
# 300  Mutilación/excisión genital de la mujer – MICS...
# 301  Justificación de golpear a la mujer – MICS, DH...
# 302  Disciplina violenta – MICS, DHS y otras encues...
#
#                                 4    5    6    7    8    9   ...  34  35  36  \
# 0                              NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# 1                              NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# 2                              NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# 3                              NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# 4    Child labour (%)+\n2005–2012*  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# ..                             ...  ...  ...  ...  ...  ...  ...  ..  ..  ..
# 298                            NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# 299                            NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# 300                            NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# 301                            NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
# 302                            NaN  NaN  NaN  NaN  NaN  NaN  ... NaN NaN NaN
#
#      37  38  39  40  41  42  43
# 0   NaN NaN NaN NaN NaN NaN NaN
# 1   NaN NaN NaN NaN NaN NaN NaN
# 2   NaN NaN NaN NaN NaN NaN NaN
# 3   NaN NaN NaN NaN NaN NaN NaN
# 4   NaN NaN NaN NaN NaN NaN NaN
# ..   ..  ..  ..  ..  ..  ..  ..
# 298 NaN NaN NaN NaN NaN NaN NaN
# 299 NaN NaN NaN NaN NaN NaN NaN
# 300 NaN NaN NaN NaN NaN NaN NaN
# 301 NaN NaN NaN NaN NaN NaN NaN
# 302 NaN NaN NaN NaN NaN NaN NaN
#
# [303 rows x 44 columns]

# %%
df = df.iloc[14:211,[1,4,6,8,10,12]].reset_index(drop=True)

# %%
df
# Out:
#                                      1     4     6     8    10    12
# 0                           Afghanistan  10.3    11   9.6   15  40.4
# 1                               Albania    12  14.4   9.4  0.2   9.6
# 2                               Algeria   4.7   5.5   3.9  0.1   1.8
# 3                               Andorra    –      –     –    –     –
# 4                                Angola  23.5  22.1  24.8    –     –
# ..                                  ...   ...   ...   ...  ...   ...
# 192  Venezuela (Bolivarian Republic of)   7.7   9.2   6.2    –     –
# 193                            Viet Nam   6.9   6.5   7.4  0.5   9.3
# 194                               Yemen  22.7  21.1  24.4   12  32.3
# 195                              Zambia  40.6  41.6  39.5  8.5  41.6
# 196                            Zimbabwe     –     –     –  3.9  30.5
#
# [197 rows x 6 columns]

# %%
names = {
    1: 'Name',
    4: 'child_labor_total',
    6: 'child_labor_male',
    8: 'child_labor_female',
    10: 'child_marriage_married_by_15',
    12: 'child_marriage_married_by_18'
    }

df.rename(columns=names)
# Out:
#                                    Name child_labor_total child_labor_male  \
# 0                           Afghanistan              10.3               11
# 1                               Albania                12             14.4
# 2                               Algeria               4.7              5.5
# 3                               Andorra                –                 –
# 4                                Angola              23.5             22.1
# ..                                  ...               ...              ...
# 192  Venezuela (Bolivarian Republic of)               7.7              9.2
# 193                            Viet Nam               6.9              6.5
# 194                               Yemen              22.7             21.1
# 195                              Zambia              40.6             41.6
# 196                            Zimbabwe                 –                –
#
#     child_labor_female child_marriage_married_by_15  \
# 0                  9.6                           15
# 1                  9.4                          0.2
# 2                  3.9                          0.1
# 3                    –                            –
# 4                 24.8                            –
# ..                 ...                          ...
# 192                6.2                            –
# 193                7.4                          0.5
# 194               24.4                           12
# 195               39.5                          8.5
# 196                  –                          3.9
#
#     child_marriage_married_by_18
# 0                           40.4
# 1                            9.6
# 2                            1.8
# 3                              –
# 4                              –
# ..                           ...
# 192                            –
# 193                          9.3
# 194                         32.3
# 195                         41.6
# 196                         30.5
#
# [197 rows x 6 columns]
